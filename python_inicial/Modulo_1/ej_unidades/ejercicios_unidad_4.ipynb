# %%
# https://cursos.utnba.centrodeelearning.com/pluginfile.php/181400/mod_book/chapter/27373/Ejercicios.pdf

""" Para trabajar con funciones lambda se debe guardar en una variable y luego pasar los parámetros de entrada a la variable como al llamar a una función, de esta forma

variabla = lambda param1, ..., parametron: operacion_sobre_paramgs
print(variable(param1,... parametronN))

 """

""" Ejercicio 1 

cree una función lambda que compruebe si un número es par o impar

"""

# par = lambda a: True if a %2 == 0  else False

# par(int(input("escriba un número")))
# if par == True:
#     print("El numero es Par")

# else:
#     print("no par")


""" Ejercicio 2


Crear una función lambda que sea equivalente a la siguiente función

def multiply_by_3(value):
    answer = 3 * value
    return answer

 """

# multiply_by_3 = lambda value: 3 * value

# print(multiply_by_3(2))

""" Ejercicio 3

Crear una función que sea equivalente a la siguiente función

def sumar(valor1, valor2):
 res = valor1 + valor2
 return res

 """

# sumar = lambda v1, v2: v1 + v2

# print(sumar(2,2))

""" Ejercicio 4 

Crear una función lambda que tome como parámetro una frase y la escriba al revés. 


"""
# frase = "hola mundo"
# resultado = lambda contardereves : frase[-1::-1]
# print(resultado(frase))


""" Ejercicio 5 

Cree un programa que utilizando una función, solicite la edad de la persona e imprima todos los años que la persona ha cumplido según el siguiente formato de ejemplo. 

1, 2, 3, 4, 5

y

5, 4, 3, 2, 1

"""

# def edad():
#     num = int(input("diga su edad"))
#     for x in range(num + 1):
#         print(x,  end=" ")

#     for x in range(0, num):

#         num -= 1
#         print("---"*8)
#         print(num,  end=" ")

# edad()

""" Ejercicio 6 

Cree una función que tome la siguiente lista y reordene de menor a mayor sus componentes:

[3, 44, 21, 78, 5, 56, 9]

"""
unordered = [3, 44, 21, 78, 5, 56, 9]
