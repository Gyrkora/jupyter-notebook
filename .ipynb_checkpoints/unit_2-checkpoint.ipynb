# %% [markdown]
# <h2>Operaciones artiméticas</h2>
#
# <h3>Resumen</h3>
#
#
# ![image.png](attachment:7b2e99e6-b853-424d-b125-9dd91238d738.png)
#
#
# <h3>More important ordenr</h3>
#
# ![image.png](attachment:56a6e83c-bdfb-4e0e-be85-35fc72a55ab5.png)
#
# ![image.png](attachment:3b67a064-7226-4658-82eb-488afaf3c9aa.png)

# %%
#ejemplo

print(3 * 3 + 3 / 3 - 3)
# Out:
# 7.0

# %%
#addition

a = 5
b = 3
result = a + b
print(result)  # Output: 8
# Out:
# 8

# %%
#substruction

a = 10
b = 7
result = a - b
print(result)  # Output: 3
# Out:
# 3

# %%
#multiplication
a = 4
b = 6
result = a * b
print(result)  # Output: 24
# Out:
# 24

# %%
#division

a = 20
b = 5
result = a / b
print(result)  # Output: 4.0
# Out:
# 4.0

# %%
#floor division

a = 20
b = 7
result = a // b
print(result)  # Output: 2
# Out:
# 2

# %%
#module %

a = 15
b = 4
result = a % b
print(result)  # Output: 3
# Out:
# 3

# %%
#exponation

a = 2
b = 3
result = a ** b
print(result)  # Output: 8
# Out:
# 8
