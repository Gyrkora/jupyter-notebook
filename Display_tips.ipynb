# %%
# videos

from IPython.display import YouTubeVideo

YouTubeVideo('B_fLW4Cq2es' , width=700, height=300)

# %%
# Iframes

from IPython.display import IFrame
IFrame("https://recursospython.com/guias-y-manuales/clases-y-orientacion-a-objetos/", width="80%", height="500px")
# Out:
#         <iframe
#             width="80%"
#             height="500px"
#             src="https://recursospython.com/guias-y-manuales/clases-y-orientacion-a-objetos/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h4><strong style="color: orange;">bibliografia</strong></h4>

# %% [markdown]
# <strong style="color: orange;">PyQT / PySide2</strong>
